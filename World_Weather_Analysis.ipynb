# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90, 90, size=1500)
lngs = np.random.uniform(-189, 189, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#import the citipy module
from citipy import citipy

# %%
# create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 597

# %%
# Import our dependencies and initialize counters and an empty list that will hold the weather data.
# Loop through the cities list.
# Group the cities in sets of 50 to log the process as we find the weather data for each city.
# Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# Build the city_url or endpoint for each city.
# Log the URL and the record and set numbers.
# Make an API request for each city.
# Parse the JSON weather data for the following:
# City, country, and date
# Latitude and longitude
# Maximum temperature
# Humidity
# Cloudiness
# Wind speed
# Add the data to a list in a dictionary format and then convert the list to a DataFrame.

# %%
# import requestst library and weather_api_key
import requests
from config import weather_api_key

# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in  sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]        
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
                                
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | asau
# Processing Record 2 of set 1 | bredasdorp
# Processing Record 3 of set 1 | freeport
# Processing Record 4 of set 1 | egvekinot
# Processing Record 5 of set 1 | burriana
# Processing Record 6 of set 1 | lorengau
# Processing Record 7 of set 1 | tiksi
# Processing Record 8 of set 1 | saint george
# Processing Record 9 of set 1 | hithadhoo
# Processing Record 10 of set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of set 1 | pangnirtung
# Processing Record 12 of set 1 | rikitea
# Processing Record 13 of set 1 | carnarvon
# Processing Record 14 of set 1 | cape town
# Processing Record 15 of set 1 | ushuaia
# Processing Record 16 of set 1 | ahipara
# Processing Record 17 of set 1 | kaitangata
# Processing Record 18 of set 1 | emerald
# Processing Record 19 of set 1 | kapaa
# Processing Record 20 of set 1 | vaini
# Processing Record 21 of set 1 | port lincoln
# Processing Record 22 of set 1 | daru
# Processing Record 23 of set 1 | nelson
# Processing Record 24 of set 1 | yellowknife
# Processing Record 25 of set 1 | odweyne
# Processing Record 26 of set 1 | thompson
# Processing Record 27 of set 1 | vestmannaeyjar
# Processing Record 28 of set 1 | samusu
# City not found. Skipping...
# Processing Record 29 of set 1 | kabanjahe
# Processing Record 30 of set 1 | port macquarie
# Processing Record 31 of set 1 | severo-kurilsk
# Processing Record 32 of set 1 | bengkulu
# Processing Record 33 of set 1 | norman wells
# Processing Record 34 of set 1 | kayerkan
# Processing Record 35 of set 1 | beitbridge
# Processing Record 36 of set 1 | inhambane
# Processing Record 37 of set 1 | butaritari
# Processing Record 38 of set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of set 1 | albany
# Processing Record 40 of set 1 | college
# Processing Record 41 of set 1 | nikolskoye
# Processing Record 42 of set 1 | avarua
# Processing Record 43 of set 1 | castro
# Processing Record 44 of set 1 | arraial do cabo
# Processing Record 45 of set 1 | atuona
# Processing Record 46 of set 1 | wakkanai
# Processing Record 47 of set 1 | port alfred
# Processing Record 48 of set 1 | davila
# Processing Record 49 of set 1 | mataura
# Processing Record 50 of set 1 | brae
# Processing Record 1 of set 2 | busselton
# Processing Record 2 of set 2 | kutum
# Processing Record 3 of set 2 | puro
# Processing Record 4 of set 2 | baft
# Processing Record 5 of set 2 | hermanus
# Processing Record 6 of set 2 | kavaratti
# Processing Record 7 of set 2 | barrow
# Processing Record 8 of set 2 | hasaki
# Processing Record 9 of set 2 | grand river south east
# City not found. Skipping...
# Processing Record 10 of set 2 | grand island
# Processing Record 11 of set 2 | leningradskiy
# Processing Record 12 of set 2 | kodiak
# Processing Record 13 of set 2 | alta floresta
# Processing Record 14 of set 2 | furstenwalde
# Processing Record 15 of set 2 | georgetown
# Processing Record 16 of set 2 | narsaq
# Processing Record 17 of set 2 | nador
# Processing Record 18 of set 2 | cururupu
# Processing Record 19 of set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of set 2 | portland
# Processing Record 21 of set 2 | new norfolk
# Processing Record 22 of set 2 | tucuman
# Processing Record 23 of set 2 | trairi
# Processing Record 24 of set 2 | arlit
# Processing Record 25 of set 2 | milkovo
# Processing Record 26 of set 2 | puerto ayora
# Processing Record 27 of set 2 | san cristobal
# Processing Record 28 of set 2 | grindavik
# Processing Record 29 of set 2 | ancud
# Processing Record 30 of set 2 | tuatapere
# Processing Record 31 of set 2 | ust-karsk
# Processing Record 32 of set 2 | dikson
# Processing Record 33 of set 2 | ejido
# Processing Record 34 of set 2 | kadykchan
# City not found. Skipping...
# Processing Record 35 of set 2 | cheyenne
# Processing Record 36 of set 2 | harper
# Processing Record 37 of set 2 | shahr-e babak
# Processing Record 38 of set 2 | ruatoria
# City not found. Skipping...
# Processing Record 39 of set 2 | saldanha
# Processing Record 40 of set 2 | duluth
# Processing Record 41 of set 2 | chuy
# Processing Record 42 of set 2 | aransas pass
# Processing Record 43 of set 2 | singaraja
# Processing Record 44 of set 2 | umm kaddadah
# Processing Record 45 of set 2 | cidreira
# Processing Record 46 of set 2 | namwala
# Processing Record 47 of set 2 | qaanaaq
# Processing Record 48 of set 2 | vilhena
# Processing Record 49 of set 2 | tyrma
# Processing Record 50 of set 2 | tatvan
# Processing Record 1 of set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 2 of set 3 | verkhnevilyuysk
# Processing Record 3 of set 3 | mattru
# Processing Record 4 of set 3 | hilo
# Processing Record 5 of set 3 | kahului
# Processing Record 6 of set 3 | georgiyevka
# Processing Record 7 of set 3 | along
# Processing Record 8 of set 3 | sitka
# Processing Record 9 of set 3 | iqaluit
# Processing Record 10 of set 3 | taoudenni
# Processing Record 11 of set 3 | codrington
# Processing Record 12 of set 3 | jamestown
# Processing Record 13 of set 3 | tomohon
# Processing Record 14 of set 3 | saskylakh
# Processing Record 15 of set 3 | port keats
# Processing Record 16 of set 3 | bluff
# Processing Record 17 of set 3 | kysyl-syr
# Processing Record 18 of set 3 | turukhansk
# Processing Record 19 of set 3 | pevek
# Processing Record 20 of set 3 | mugur-aksy
# Processing Record 21 of set 3 | abadan
# Processing Record 22 of set 3 | punta arenas
# Processing Record 23 of set 3 | khatanga
# Processing Record 24 of set 3 | lavrentiya
# Processing Record 25 of set 3 | tuktoyaktuk
# Processing Record 26 of set 3 | namatanai
# Processing Record 27 of set 3 | nguiu
# City not found. Skipping...
# Processing Record 28 of set 3 | waipawa
# Processing Record 29 of set 3 | embu
# Processing Record 30 of set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of set 3 | east london
# Processing Record 32 of set 3 | samarai
# Processing Record 33 of set 3 | xinqing
# Processing Record 34 of set 3 | acarau
# Processing Record 35 of set 3 | vila velha
# Processing Record 36 of set 3 | bogorodskoye
# Processing Record 37 of set 3 | amapa
# Processing Record 38 of set 3 | fare
# Processing Record 39 of set 3 | ilulissat
# Processing Record 40 of set 3 | marzuq
# Processing Record 41 of set 3 | salalah
# Processing Record 42 of set 3 | morondava
# Processing Record 43 of set 3 | beringovskiy
# Processing Record 44 of set 3 | kavieng
# Processing Record 45 of set 3 | rize
# Processing Record 46 of set 3 | heihe
# Processing Record 47 of set 3 | pisco
# Processing Record 48 of set 3 | ixtapa
# Processing Record 49 of set 3 | mandera
# Processing Record 50 of set 3 | hambantota
# Processing Record 1 of set 4 | san patricio
# Processing Record 2 of set 4 | saint-augustin
# Processing Record 3 of set 4 | ushtobe
# Processing Record 4 of set 4 | vostok
# Processing Record 5 of set 4 | bambous virieux
# Processing Record 6 of set 4 | amderma
# City not found. Skipping...
# Processing Record 7 of set 4 | bafoulabe
# Processing Record 8 of set 4 | nemuro
# Processing Record 9 of set 4 | manokwari
# Processing Record 10 of set 4 | nantucket
# Processing Record 11 of set 4 | hofn
# Processing Record 12 of set 4 | tiarei
# Processing Record 13 of set 4 | madimba
# Processing Record 14 of set 4 | provideniya
# Processing Record 15 of set 4 | bambanglipuro
# Processing Record 16 of set 4 | tasiilaq
# Processing Record 17 of set 4 | cabo san lucas
# Processing Record 18 of set 4 | lebu
# Processing Record 19 of set 4 | navahrudak
# Processing Record 20 of set 4 | guerrero negro
# Processing Record 21 of set 4 | naze
# Processing Record 22 of set 4 | dese
# Processing Record 23 of set 4 | sibolga
# Processing Record 24 of set 4 | bellevue
# Processing Record 25 of set 4 | houma
# Processing Record 26 of set 4 | mogocha
# Processing Record 27 of set 4 | bonavista
# Processing Record 28 of set 4 | klaksvik
# Processing Record 29 of set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of set 4 | kyzyl
# Processing Record 31 of set 4 | houston
# Processing Record 32 of set 4 | namibe
# Processing Record 33 of set 4 | abu kamal
# Processing Record 34 of set 4 | tambul
# City not found. Skipping...
# Processing Record 35 of set 4 | isangel
# Processing Record 36 of set 4 | mahanoro
# Processing Record 37 of set 4 | hobart
# Processing Record 38 of set 4 | port elizabeth
# Processing Record 39 of set 4 | bathsheba
# Processing Record 40 of set 4 | las choapas
# Processing Record 41 of set 4 | beloha
# Processing Record 42 of set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of set 4 | tumannyy
# City not found. Skipping...
# Processing Record 45 of set 4 | husavik
# Processing Record 46 of set 4 | fomboni
# Processing Record 47 of set 4 | belushya guba
# City not found. Skipping...
# Processing Record 48 of set 4 | te anau
# Processing Record 49 of set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 50 of set 4 | dunedin
# Processing Record 1 of set 5 | road town
# Processing Record 2 of set 5 | tabiauea
# City not found. Skipping...
# Processing Record 3 of set 5 | siyabuswa
# Processing Record 4 of set 5 | kashipur
# Processing Record 5 of set 5 | guarapari
# Processing Record 6 of set 5 | wodonga
# Processing Record 7 of set 5 | chokurdakh
# Processing Record 8 of set 5 | tolaga bay
# Processing Record 9 of set 5 | yeppoon
# Processing Record 10 of set 5 | clyde river
# Processing Record 11 of set 5 | najran
# Processing Record 12 of set 5 | vardo
# Processing Record 13 of set 5 | benguela
# Processing Record 14 of set 5 | mar del plata
# Processing Record 15 of set 5 | thohoyandou
# Processing Record 16 of set 5 | baghdad
# Processing Record 17 of set 5 | vao
# Processing Record 18 of set 5 | yomitan
# City not found. Skipping...
# Processing Record 19 of set 5 | concarneau
# Processing Record 20 of set 5 | axim
# Processing Record 21 of set 5 | antalaha
# Processing Record 22 of set 5 | yumen
# Processing Record 23 of set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of set 5 | saint-joseph
# Processing Record 25 of set 5 | nurota
# Processing Record 26 of set 5 | belmonte
# Processing Record 27 of set 5 | bethel
# Processing Record 28 of set 5 | aklavik
# Processing Record 29 of set 5 | pundaguitan
# Processing Record 30 of set 5 | sao filipe
# Processing Record 31 of set 5 | pokhara
# Processing Record 32 of set 5 | mehamn
# Processing Record 33 of set 5 | mount gambier
# Processing Record 34 of set 5 | faanui
# Processing Record 35 of set 5 | geraldton
# Processing Record 36 of set 5 | vredendal
# Processing Record 37 of set 5 | lompoc
# Processing Record 38 of set 5 | ribeira grande
# Processing Record 39 of set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of set 5 | zyryanka
# Processing Record 41 of set 5 | shingu
# Processing Record 42 of set 5 | otradnoye
# Processing Record 43 of set 5 | flin flon
# Processing Record 44 of set 5 | morehead
# Processing Record 45 of set 5 | cortez
# Processing Record 46 of set 5 | kruisfontein
# Processing Record 47 of set 5 | burica
# City not found. Skipping...
# Processing Record 48 of set 5 | fairbanks
# Processing Record 49 of set 5 | marawi
# Processing Record 50 of set 5 | mahebourg
# Processing Record 1 of set 6 | kangaatsiaq
# Processing Record 2 of set 6 | springdale
# Processing Record 3 of set 6 | belomorsk
# Processing Record 4 of set 6 | korla
# Processing Record 5 of set 6 | north bend
# Processing Record 6 of set 6 | lufilufi
# Processing Record 7 of set 6 | fuyu
# Processing Record 8 of set 6 | buala
# Processing Record 9 of set 6 | rawson
# Processing Record 10 of set 6 | qaqortoq
# Processing Record 11 of set 6 | grafton
# Processing Record 12 of set 6 | wanning
# Processing Record 13 of set 6 | tabory
# Processing Record 14 of set 6 | nkoteng
# Processing Record 15 of set 6 | talnakh
# Processing Record 16 of set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of set 6 | ponta delgada
# Processing Record 18 of set 6 | shebunino
# Processing Record 19 of set 6 | barcelos
# Processing Record 20 of set 6 | hobyo
# Processing Record 21 of set 6 | kenora
# Processing Record 22 of set 6 | saint-michel-des-saints
# Processing Record 23 of set 6 | victoria
# Processing Record 24 of set 6 | noumea
# Processing Record 25 of set 6 | sur
# Processing Record 26 of set 6 | alice springs
# Processing Record 27 of set 6 | papara
# Processing Record 28 of set 6 | gorom-gorom
# Processing Record 29 of set 6 | svetlyy
# Processing Record 30 of set 6 | hong gai
# Processing Record 31 of set 6 | karratha
# Processing Record 32 of set 6 | darhan
# Processing Record 33 of set 6 | saint-philippe
# Processing Record 34 of set 6 | fengzhen
# Processing Record 35 of set 6 | kantang
# Processing Record 36 of set 6 | vallenar
# Processing Record 37 of set 6 | salinopolis
# Processing Record 38 of set 6 | san quintin
# Processing Record 39 of set 6 | tadine
# Processing Record 40 of set 6 | nhulunbuy
# Processing Record 41 of set 6 | seymchan
# Processing Record 42 of set 6 | souillac
# Processing Record 43 of set 6 | vila franca do campo
# Processing Record 44 of set 6 | toliary
# City not found. Skipping...
# Processing Record 45 of set 6 | half moon bay
# Processing Record 46 of set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of set 6 | vaitupu
# City not found. Skipping...
# Processing Record 48 of set 6 | kazanskoye
# Processing Record 49 of set 6 | ongandjera
# Processing Record 50 of set 6 | batagay
# Processing Record 1 of set 7 | sao felix do xingu
# Processing Record 2 of set 7 | marshall
# Processing Record 3 of set 7 | barawe
# City not found. Skipping...
# Processing Record 4 of set 7 | bay roberts
# Processing Record 5 of set 7 | ardabil
# Processing Record 6 of set 7 | tuggurt
# City not found. Skipping...
# Processing Record 7 of set 7 | lucea
# Processing Record 8 of set 7 | wilmington
# Processing Record 9 of set 7 | noshiro
# Processing Record 10 of set 7 | touros
# Processing Record 11 of set 7 | nome
# Processing Record 12 of set 7 | elva
# Processing Record 13 of set 7 | ponta do sol
# Processing Record 14 of set 7 | airai
# Processing Record 15 of set 7 | dongsheng
# Processing Record 16 of set 7 | naousa
# Processing Record 17 of set 7 | sao joao da barra
# Processing Record 18 of set 7 | bargal
# City not found. Skipping...
# Processing Record 19 of set 7 | hanyang
# Processing Record 20 of set 7 | christchurch
# Processing Record 21 of set 7 | bradford
# Processing Record 22 of set 7 | punta alta
# Processing Record 23 of set 7 | kieta
# Processing Record 24 of set 7 | tahe
# Processing Record 25 of set 7 | mettur
# Processing Record 26 of set 7 | caravelas
# Processing Record 27 of set 7 | vanimo
# Processing Record 28 of set 7 | creel
# Processing Record 29 of set 7 | swan river
# Processing Record 30 of set 7 | santa cruz
# Processing Record 31 of set 7 | senneterre
# Processing Record 32 of set 7 | port hedland
# Processing Record 33 of set 7 | westport
# Processing Record 34 of set 7 | canoa
# Processing Record 35 of set 7 | xadani
# City not found. Skipping...
# Processing Record 36 of set 7 | thinadhoo
# Processing Record 37 of set 7 | coyoles
# Processing Record 38 of set 7 | tamandare
# Processing Record 39 of set 7 | cervo
# Processing Record 40 of set 7 | gat
# Processing Record 41 of set 7 | evensk
# Processing Record 42 of set 7 | monrovia
# Processing Record 43 of set 7 | meulaboh
# Processing Record 44 of set 7 | sioux lookout
# Processing Record 45 of set 7 | amparafaravola
# Processing Record 46 of set 7 | san borja
# Processing Record 47 of set 7 | nyuzen
# Processing Record 48 of set 7 | hailar
# Processing Record 49 of set 7 | rocha
# Processing Record 50 of set 7 | avera
# Processing Record 1 of set 8 | hai duong
# Processing Record 2 of set 8 | kudahuvadhoo
# Processing Record 3 of set 8 | ariano irpino
# Processing Record 4 of set 8 | lolua
# City not found. Skipping...
# Processing Record 5 of set 8 | halalo
# City not found. Skipping...
# Processing Record 6 of set 8 | xai-xai
# Processing Record 7 of set 8 | esperance
# Processing Record 8 of set 8 | lumut
# Processing Record 9 of set 8 | fatehpur
# Processing Record 10 of set 8 | praia
# Processing Record 11 of set 8 | oloron-sainte-marie
# Processing Record 12 of set 8 | moses lake
# Processing Record 13 of set 8 | henderson
# Processing Record 14 of set 8 | san francisco
# Processing Record 15 of set 8 | tunxi
# City not found. Skipping...
# Processing Record 16 of set 8 | necochea
# Processing Record 17 of set 8 | lahij
# Processing Record 18 of set 8 | yelkhovka
# Processing Record 19 of set 8 | orlik
# Processing Record 20 of set 8 | altamira
# Processing Record 21 of set 8 | maragogi
# Processing Record 22 of set 8 | pasni
# Processing Record 23 of set 8 | manaure
# Processing Record 24 of set 8 | abatskoye
# Processing Record 25 of set 8 | kachug
# Processing Record 26 of set 8 | douglasville
# Processing Record 27 of set 8 | tiznit
# Processing Record 28 of set 8 | seminole
# Processing Record 29 of set 8 | sinkat
# City not found. Skipping...
# Processing Record 30 of set 8 | dolores
# Processing Record 31 of set 8 | nambucca heads
# Processing Record 32 of set 8 | ascension
# Processing Record 33 of set 8 | tome-acu
# City not found. Skipping...
# Processing Record 34 of set 8 | voskresenskoye
# Processing Record 35 of set 8 | saint-pierre
# Processing Record 36 of set 8 | yulara
# Processing Record 37 of set 8 | okha
# Processing Record 38 of set 8 | hovd
# Processing Record 39 of set 8 | halifax
# Processing Record 40 of set 8 | jati
# Processing Record 41 of set 8 | singaparna
# Processing Record 42 of set 8 | zatoka
# Processing Record 43 of set 8 | nyurba
# Processing Record 44 of set 8 | tarudant
# City not found. Skipping...
# Processing Record 45 of set 8 | hirara
# Processing Record 46 of set 8 | gondanglegi
# Processing Record 47 of set 8 | petropavl
# Processing Record 48 of set 8 | tezu
# Processing Record 49 of set 8 | coahuayana
# Processing Record 50 of set 8 | dafeng
# Processing Record 1 of set 9 | vurnary
# Processing Record 2 of set 9 | kawana waters
# City not found. Skipping...
# Processing Record 3 of set 9 | ulvik
# Processing Record 4 of set 9 | goba
# Processing Record 5 of set 9 | banff
# Processing Record 6 of set 9 | constitucion
# Processing Record 7 of set 9 | hamilton
# Processing Record 8 of set 9 | podgornoye
# Processing Record 9 of set 9 | port hueneme
# Processing Record 10 of set 9 | giraldo
# Processing Record 11 of set 9 | lesozavodsk
# Processing Record 12 of set 9 | puerto penasco
# Processing Record 13 of set 9 | zeya
# Processing Record 14 of set 9 | tyup
# Processing Record 15 of set 9 | nisia floresta
# Processing Record 16 of set 9 | upernavik
# Processing Record 17 of set 9 | putina
# Processing Record 18 of set 9 | kurtamysh
# Processing Record 19 of set 9 | dingle
# Processing Record 20 of set 9 | san ramon
# Processing Record 21 of set 9 | komsomolskiy
# Processing Record 22 of set 9 | poya
# Processing Record 23 of set 9 | ouesso
# Processing Record 24 of set 9 | khorinsk
# Processing Record 25 of set 9 | ciudad bolivar
# Processing Record 26 of set 9 | kameno
# Processing Record 27 of set 9 | muroto
# Processing Record 28 of set 9 | moindou
# Processing Record 29 of set 9 | wadsworth
# Processing Record 30 of set 9 | ziro
# Processing Record 31 of set 9 | anadyr
# Processing Record 32 of set 9 | tiruvottiyur
# City not found. Skipping...
# Processing Record 33 of set 9 | ingham
# Processing Record 34 of set 9 | gambela
# Processing Record 35 of set 9 | zamora
# Processing Record 36 of set 9 | minsk
# Processing Record 37 of set 9 | saquena
# Processing Record 38 of set 9 | nelson bay
# Processing Record 39 of set 9 | cap malheureux
# Processing Record 40 of set 9 | kousseri
# Processing Record 41 of set 9 | port hardy
# Processing Record 42 of set 9 | bayir
# Processing Record 43 of set 9 | sasolburg
# Processing Record 44 of set 9 | rairangpur
# Processing Record 45 of set 9 | altus
# Processing Record 46 of set 9 | taburao
# City not found. Skipping...
# Processing Record 47 of set 9 | tateyama
# Processing Record 48 of set 9 | karauzyak
# City not found. Skipping...
# Processing Record 49 of set 9 | laredo
# Processing Record 50 of set 9 | itaporanga
# Processing Record 1 of set 10 | bilibino
# Processing Record 2 of set 10 | chongwe
# Processing Record 3 of set 10 | nacala
# Processing Record 4 of set 10 | derzhavinsk
# Processing Record 5 of set 10 | panguna
# Processing Record 6 of set 10 | laguna de perlas
# Processing Record 7 of set 10 | gazli
# Processing Record 8 of set 10 | aranda de duero
# Processing Record 9 of set 10 | kloulklubed
# Processing Record 10 of set 10 | mareeba
# Processing Record 11 of set 10 | sao borja
# Processing Record 12 of set 10 | roma
# Processing Record 13 of set 10 | zhigansk
# Processing Record 14 of set 10 | natal
# Processing Record 15 of set 10 | alimanguan
# City not found. Skipping...
# Processing Record 16 of set 10 | yabelo
# Processing Record 17 of set 10 | kasongo-lunda
# Processing Record 18 of set 10 | keffi
# Processing Record 19 of set 10 | broken hill
# Processing Record 20 of set 10 | port-gentil
# Processing Record 21 of set 10 | araouane
# Processing Record 22 of set 10 | ossora
# Processing Record 23 of set 10 | mgachi
# Processing Record 24 of set 10 | bara
# Processing Record 25 of set 10 | cairns
# Processing Record 26 of set 10 | pervoavgustovskiy
# Processing Record 27 of set 10 | srednekolymsk
# Processing Record 28 of set 10 | pandan
# Processing Record 29 of set 10 | sola
# Processing Record 30 of set 10 | luderitz
# Processing Record 31 of set 10 | rungata
# City not found. Skipping...
# Processing Record 32 of set 10 | grand forks
# Processing Record 33 of set 10 | zigong
# Processing Record 34 of set 10 | oranjestad
# Processing Record 35 of set 10 | bredy
# Processing Record 36 of set 10 | pauini
# Processing Record 37 of set 10 | flinders
# Processing Record 38 of set 10 | koumac
# Processing Record 39 of set 10 | quatre cocos
# Processing Record 40 of set 10 | kuandian
# Processing Record 41 of set 10 | virginia beach
# Processing Record 42 of set 10 | omaruru
# Processing Record 43 of set 10 | karatau
# Processing Record 44 of set 10 | varhaug
# Processing Record 45 of set 10 | homer
# Processing Record 46 of set 10 | batagay-alyta
# Processing Record 47 of set 10 | chulym
# Processing Record 48 of set 10 | muros
# Processing Record 49 of set 10 | kosh-agach
# Processing Record 50 of set 10 | calvia
# Processing Record 1 of set 11 | longyearbyen
# Processing Record 2 of set 11 | atasu
# Processing Record 3 of set 11 | stupino
# Processing Record 4 of set 11 | burnie
# Processing Record 5 of set 11 | saleaula
# City not found. Skipping...
# Processing Record 6 of set 11 | grand-lahou
# Processing Record 7 of set 11 | pinega
# Processing Record 8 of set 11 | krasnoznamensk
# Processing Record 9 of set 11 | buarcos
# Processing Record 10 of set 11 | torbay
# Processing Record 11 of set 11 | hay river
# Processing Record 12 of set 11 | dubti
# Processing Record 13 of set 11 | ola
# Processing Record 14 of set 11 | umm lajj
# Processing Record 15 of set 11 | aleksandrovskoye
# Processing Record 16 of set 11 | coquimbo
# Processing Record 17 of set 11 | lata
# Processing Record 18 of set 11 | castanos
# Processing Record 19 of set 11 | ippy
# Processing Record 20 of set 11 | werda
# Processing Record 21 of set 11 | konin
# Processing Record 22 of set 11 | richards bay
# Processing Record 23 of set 11 | balta
# Processing Record 24 of set 11 | mikhaylovka
# Processing Record 25 of set 11 | bilma
# Processing Record 26 of set 11 | katobu
# Processing Record 27 of set 11 | taltal
# Processing Record 28 of set 11 | georgiyevskoye
# Processing Record 29 of set 11 | ukiah
# Processing Record 30 of set 11 | la asuncion
# Processing Record 31 of set 11 | bom jesus
# Processing Record 32 of set 11 | karasjok
# Processing Record 33 of set 11 | katubao
# Processing Record 34 of set 11 | keelung
# Processing Record 35 of set 11 | makakilo city
# Processing Record 36 of set 11 | fulitun
# City not found. Skipping...
# Processing Record 37 of set 11 | kongolo
# Processing Record 38 of set 11 | dawson creek
# Processing Record 39 of set 11 | sitio novo do tocantins
# Processing Record 40 of set 11 | pontal do parana
# Processing Record 41 of set 11 | weinan
# Processing Record 42 of set 11 | espirito santo do pinhal
# Processing Record 43 of set 11 | sorland
# Processing Record 44 of set 11 | marsh harbour
# Processing Record 45 of set 11 | kegayli
# City not found. Skipping...
# Processing Record 46 of set 11 | belyy yar
# Processing Record 47 of set 11 | zhigalovo
# Processing Record 48 of set 11 | crotone
# Processing Record 49 of set 11 | sao gabriel da cachoeira
# Processing Record 50 of set 11 | kytlym
# City not found. Skipping...
# Processing Record 1 of set 12 | cherskiy
# Processing Record 2 of set 12 | dubbo
# Processing Record 3 of set 12 | monduli
# Processing Record 4 of set 12 | mocuba
# Processing Record 5 of set 12 | narasannapeta
# Processing Record 6 of set 12 | chicama
# Processing Record 7 of set 12 | dibulla
# Processing Record 8 of set 12 | purranque
# Processing Record 9 of set 12 | storsteinnes
# Processing Record 10 of set 12 | yidu
# Processing Record 11 of set 12 | redding
# Processing Record 12 of set 12 | provost
# Processing Record 13 of set 12 | tabou
# Processing Record 14 of set 12 | kuche
# City not found. Skipping...
# Processing Record 15 of set 12 | linguere
# Processing Record 16 of set 12 | cerrito
# Processing Record 17 of set 12 | walvis bay
# Processing Record 18 of set 12 | sobreira
# Processing Record 19 of set 12 | porto walter
# Processing Record 20 of set 12 | corowa
# Processing Record 21 of set 12 | aviles
# Processing Record 22 of set 12 | novokayakent
# Processing Record 23 of set 12 | banda aceh
# Processing Record 24 of set 12 | duku
# Processing Record 25 of set 12 | bam
# Processing Record 26 of set 12 | bubaque
# Processing Record 27 of set 12 | sabang
# Processing Record 28 of set 12 | tabialan
# City not found. Skipping...
# Processing Record 29 of set 12 | tres arroyos
# Processing Record 30 of set 12 | kushima
# Processing Record 31 of set 12 | mackay
# Processing Record 32 of set 12 | volsk
# Processing Record 33 of set 12 | ostrovnoy
# Processing Record 34 of set 12 | villa carlos paz
# Processing Record 35 of set 12 | aasiaat
# Processing Record 36 of set 12 | bejar
# Processing Record 37 of set 12 | neuquen
# Processing Record 38 of set 12 | kurtalan
# Processing Record 39 of set 12 | marcona
# City not found. Skipping...
# Processing Record 40 of set 12 | januaria
# Processing Record 41 of set 12 | son la
# Processing Record 42 of set 12 | acapulco
# Processing Record 43 of set 12 | mayo
# Processing Record 44 of set 12 | los llanos de aridane
# Processing Record 45 of set 12 | lazaro cardenas
# Processing Record 46 of set 12 | nanortalik
# Processing Record 47 of set 12 | tundla
# -----------------------------
# Data Retrieval Complete
# -----------------------------
